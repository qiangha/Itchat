# %% [markdown]
# This is intended to be a birthday gift for my friend Vernica. The aim is to show her a snapshot of her social circle on wechat on her birthday. Hope she will enjoy it. I enjoyed making it.

# %%
from main import starter
    

if __name__ == "__main__":
    starter()
# Out:
# Dear Vernica:
#
# It is a real pleasure to travel with you and be friend with you.
#
# Thank you for all the beautiful photos and beautiful memories.
#
# Let us build many more memories together in the time to come!
#
# Though I am physically absent, my heart is with you celebrating.
#
# Wish you a very good birthday!
#
#
#
#
#
# Here is my present for you.
#
# It is a python programme that shows your Wechat friend info.
#
#
#
# By gender
#
# By location
#
# By strength (number of common chatrooms you are in)
#
#
#
# Please scan the QR code using Wechat when it pops up.
#
# And open the map.html to see friend distribution by location.
#
# Hope you enjoy it.
#
# HAHA
# itchat has already logged in.
